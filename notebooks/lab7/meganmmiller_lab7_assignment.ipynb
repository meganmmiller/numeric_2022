# %% [markdown]
# <h2>Import Statements<h2>

# %%
import context
from IPython.display import Image
import IPython.display as display
# import plotting package and numerical python package for use in examples later
import matplotlib.pyplot as plt
# make the plots happen inline
# %matplotlib inline  
# import the numpy array handling library
import numpy as np


#Importing my modified rain.py file that is the answer for Question 5. 
from numlabs.lab7 import meganmmiller_rain
# Out:
# ******************************
# context imported. Front of path:
# C:\Users\megan\repos\numeric_2022
# back of path: C:\Users\megan\AppData\Roaming\Python\Python39\site-packages
# ******************************
#
# through c:\Users\megan\repos\numeric_2022\notebooks\lab7\context.py

# %% [markdown]
# ### Problem Four Question
#
# [lab7:prob:accurate]:(#Problem-Four)
#
# Which grid gives the best accuracy for $d=R/2$?
# Explain in what ways it is more accurate.

# %% [markdown]
# ### Problem Four Answer
#
# Based on the graphs in the lab 7 notebook, Grid 2 appears more accurate at d=R/2 because the numerical solution waveform is closest to the actual wave form.  Both Grid 1 and Grid 2 are more accurate (and almost undiscernible from each other and the actual wave form) when -1 <kd <1.

# %% [markdown]
# ### Problem Five Question
#
# [lab7:prob:noy]:(#Problem-Five)
#
# Modify *rain.py* to solve equations
# ([No variation in y, first eqn](#lab7:sec:firsteq)), ([No variation in y, second eqn](#lab7:sec:secondeq)) and ([No variation in y, third eqn](#lab7:sec:thirdeq)) on the most accurate
# grid.

# %% [markdown]
# ### Problem Five Answer
#
# The modified rain file is called meganmmiller_rain.py.  Scans of the calculations sheets used to derive the changes to the file are attached to the back of this PDF.  Below is the results of running the modified file.
#
# Note that based on equations in Pond and Pickard (1983), f was assumed to be:\
# $f=2 \Omega sin \phi$\
# where:\
# $\Omega$ = speed of earth's rotation= $7.29x10^{-5}$ rads/s\
# $\phi$ = geographic latitude, assumed to be $50^o$ for this calculation

# %%
meganmmiller_rain.rain([100,15])

# %% [markdown]
# Since h $\neq$ 0 at grid points 1,3,5,7,9,11,13, and u $\neq$ 0 and v $\neq$ 0 at grid points 2,4,6,8,10,12,14; it appears as though I have achieved Grid 2, which I was aiming for.
